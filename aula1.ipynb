# %% [markdown]
# # O que vamos aprender?

# %% [markdown]
# - O que é Numpy
# - Manipular arrays (ndarray)
# - Indexação
# - Operações vetorizadas
# - Algebra Linear e Estatística (Probabilidade e Est. Bayesiana)
# - Performance: NumPy vs. Listas Nativas Python
# - Boas práticas e solução do projeto

# %%
print("Thomas Bayes vai revirar no túmulo!")
# Out:
# Thomas Bayes vai revirar no túmulo!

# %% [markdown]
# #### Por que o NumPy é o coração da ciencia de dados em Python?

# %% [markdown]
# - Pandas
# - Sciki-learn
# - TensorFlow (redes neurais)
# - MatplotLib

# %%
import numpy as np

# %% [markdown]
# - Lista do Python x Array do NumPy

# %% [markdown]
# - Vetor ou Matriz Unidimensional

# %% [markdown]
# ### Porque o NumPy Array e mais rapido que uma lista Python

# %% [markdown]
# - Lista e a sacola do supermercado
# - Array do NumPy - caixa de ovos
# - C e Fortran: 50x
# - O NymPy permite a vetorizacao

# %% [markdown]
# # Aula 1 - Download de DataSets

# %% [markdown]
# - Iris
# - Petrobras (acoes)
# - Macas

# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.3.4'

# %%
np.loadtxt('datasets/iris_lucio.csv', delimiter=',',skiprows=1, usecols=(0,1,2,3))
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
# Mostrar o tamanho do array
data_iris = np.loadtxt('datasets/iris_Lucio.csv', delimiter=',',skiprows=1, usecols=(0,1,2,3))
print(data_iris.shape)
# Out:
# (150, 4)

# %% [markdown]
# ### Considerações

# %% [markdown]
# - Biblioteca matemática e cientifica
# - Aplica-se matemática e estatística com o uso de Arrays

# %% [markdown]
# ### O que podemos fazer?

# %% [markdown]
# - Realizar operações com objetos dos tipos Arrays
# - São parecidas com a do Python
# - Menos memória ocupada
# - Série de métodos atrelados aos Arrays

# %% [markdown]
# ### Nossos DataSets

# %% [markdown]
# #### Iris (O nosso Hello Data Cience!!!)
# - O conjunto de dados Iris é um clássico em estatística e aprendizado de máquina.
# - Os dados foram coletados por Edgar Anderson e popularizados por Ronald A. Fisher em 1936 no artigo "The use of multiple measurements in taxonomic problems", onde Fisher usou-os para demonstrar análise discriminante linear.
# - Contém 150 amostras de três espécies de Iris (I. setosa, I. versicolor, I. virginica), com quatro medidas: comprimento/largura das sépalas e pétalas.
# - Por ser pequeno, bem comportado e fácil de visualizar, tornou-se um exemplo padrão para ensinar métodos de classificação, visualização e validação de modelos.
# - Hoje é amplamente disponível em repositórios como o UCI Machine Learning Repository e em bibliotecas estatísticas e de ML.

# %% [markdown]
# #### Petrobras.xlsx
#
# - Quando se trabalha ou se investe no mercado financeiro, uma das operações mais frequentes é o cálculo do retorno financeiro.
# - É o retorno que vai dizer se uma ação tem,
# em média, uma rentabilidade melhor que outra. Ou é o retorno que vai dizer se a volatilidade (desvio-padrão) é maior em um ativo em comparação com outro tipo de ativo.
# - Vinte dados de uma opção da Petrobras foram adquiridos a cada 5 minutos de um terminal e armazenados em uma planilha do Excel. O nome desse arquivo é Petrobras.xlsx

# %% [markdown]
# Fórmula do retorno financeiro: ![image.png](attachment:image.png)

# %% [markdown]
# #### Apples.csv

# %% [markdown]
# - Cada linha é uma cidade da Russia
# - Cada coluna é uma data (mes-ano) onde registramos os preços das maças
# - São doze anos de informação carregadas no dataset

# %% [markdown]
# ### Nossas Bibliotecas

# %% [markdown]
# - Três bibliotecas tornam-se essenciais no desenvolvimento de cálculos mais avan-
# çados e colaboram com a ampliação do espectro de análises já proporcionada pela
# biblioteca de estatística.
# - A biblioteca numpy (numerical Python) é fundamental na computação científica
# em Python, aumentando as funcionalidades para o uso de array (vetores e matrizes)
# e auxiliando em muitas atividades.
# - As bibliotecas scipy (scientific Python)
# - Pandas (Python data analysis library)
# - Matplotlib (plotting library) completam o pacote essencial para gráficos, análises de tabelas, como a tabela dinâmica no Excel (pivot table) chamada DataFrame, e algoritmos para cálculos com vetores e matrizes.
# - Com esse DataSet iremos aplicar as bibliotecas: Pandas, NumPy e MatplotLib e recursos de acessos a planilhas eletrônicas.

# %% [markdown]
# # EDA Iris com NumPy

# %% [markdown]
# - As colunas devem ter um tipo (Array do NumPy aceita apenas um tipo de dados)

# %%
# mostrar as 5 primeiras linhas do array
data_iris[:5]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
# mostrar o tamanho do array
data_iris.shape
# Out:
# (150, 4)

# %%
# mostrar o tipo de dado do array
data_iris.dtype
# Out:
# dtype('float64')

# %%
# somar todos os valores da linha 0
data_iris[0].sum()
# Out:
# np.float64(10.2)

# %%
# proponha operações no array
print(f"média de cada coluna{data_iris.mean(axis=0)}")  # média de cada coluna
print(f"desvio padrão de cada coluna {data_iris.std(axis=0)}")  # desvio padrão de cada coluna
print(f"valor máximo de cada coluna {data_iris.max(axis=0)}")  # valor máximo de cada coluna
print(f"valor mínimo de cada coluna {data_iris.min(axis=0)}")  # valor mínimo de cada coluna
# calcular a média da coluna 0
data_iris[:,0].mean()
data_iris[:,0].std()
data_iris[:,0].max()
data_iris[:,0].min()
data_iris[:,0].sum()
data_iris[:,0].var()  # variância da coluna 0
data_iris[:,0].cumsum()  # soma acumulada da coluna 0
data_iris[:,0].prod()  # produto dos valores da coluna 0
data_iris[:,0].round(2)  # arredondar os valores da coluna 0 para 2 casas decimais
data_iris[:,0].astype(int)  # converter os valores da coluna 0 para inteiros
data_iris[:,0] > 5.0  # valores da coluna 0 maiores que 5.0
data_iris[data_iris[:,0] > 5.0]  # linhas onde a coluna 0 é maior que 5.0
data_iris[:,0][data_iris[:,0] > 5.0]  # valores da coluna 0 maiores que 5.0
data_iris[:,0].argsort()  # índices que ordenariam a coluna 0
data_iris[data_iris[:,0].argsort()]  # ordenar o array pela coluna 0
# Out:
# média de cada coluna[5.84333333 3.054      3.75866667 1.19866667]
# desvio padrão de cada coluna [0.82530129 0.43214658 1.75852918 0.76061262]
# valor máximo de cada coluna [7.9 4.4 6.9 2.5]
# valor mínimo de cada coluna [4.3 2.  1.  0.1]
# array([[4.3, 3. , 1.1, 0.1],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.4, 3.2, 1.3, 0.2],
#        [4.4, 3. , 1.3, 0.2],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.6, 3.6, 1. , 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [4.6, 3.4, 1.4, 0.3],
#        [4.6, 3.2, 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.3],
#        [4.8, 3.1, 1.6, 0.2],
#        [4.8, 3.4, 1.9, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.9, 2.4, 3.3, 1. ],
#        [4.9, 3.1, 1.5, 0.1],
#        [4.9, 3.1, 1.5, 0.1],
#        [4.9, 3. , 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [5. , 3.5, 1.3, 0.3],
#        [5. , 3.3, 1.4, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5. , 3.4, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5. , 2. , 3.5, 1. ],
#        [5. , 3.2, 1.2, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [5.1, 3.5, 1.4, 0.2],
#        [5.1, 3.8, 1.9, 0.4],
#        [5.1, 3.4, 1.5, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.2, 2.7, 3.9, 1.4],
#        [5.2, 3.4, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.4, 3. , 4.5, 1.5],
#        [5.4, 3.7, 1.5, 0.2],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.5, 4.2, 1.4, 0.2],
#        [5.5, 2.3, 4. , 1.3],
#        [5.5, 3.5, 1.3, 0.2],
#        [5.5, 2.6, 4.4, 1.2],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.5, 4. , 1.3],
#        [5.6, 2.9, 3.6, 1.3],
#        [5.6, 3. , 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.6, 3. , 4.1, 1.3],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [5.7, 2.8, 4.1, 1.3],
#        [5.7, 2.9, 4.2, 1.3],
#        [5.7, 2.8, 4.5, 1.3],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.7, 2.5, 5. , 2. ],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.8, 4. , 1.2, 0.2],
#        [5.8, 2.8, 5.1, 2.4],
#        [5.8, 2.7, 5.1, 1.9],
#        [5.8, 2.7, 3.9, 1.2],
#        [5.8, 2.7, 4.1, 1. ],
#        [5.8, 2.6, 4. , 1.2],
#        [5.8, 2.7, 5.1, 1.9],
#        [5.9, 3.2, 4.8, 1.8],
#        [5.9, 3. , 4.2, 1.5],
#        [5.9, 3. , 5.1, 1.8],
#        [6. , 2.9, 4.5, 1.5],
#        [6. , 2.2, 5. , 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6. , 3.4, 4.5, 1.6],
#        [6. , 2.7, 5.1, 1.6],
#        [6. , 3. , 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.1, 2.8, 4. , 1.3],
#        [6.1, 2.6, 5.6, 1.4],
#        [6.1, 3. , 4.6, 1.4],
#        [6.1, 2.9, 4.7, 1.4],
#        [6.2, 2.2, 4.5, 1.5],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.2, 2.9, 4.3, 1.3],
#        [6.2, 3.4, 5.4, 2.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.3, 3.3, 6. , 2.5],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.3, 3.3, 4.7, 1.6],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.3, 2.5, 5. , 1.9],
#        [6.3, 2.3, 4.4, 1.3],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.4, 3.1, 5.5, 1.8],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.4, 2.8, 5.6, 2.1],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.5, 3. , 5.2, 2. ],
#        [6.5, 3. , 5.5, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [6.5, 2.8, 4.6, 1.5],
#        [6.6, 2.9, 4.6, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.7, 3.3, 5.7, 2.1],
#        [6.7, 3.1, 4.4, 1.4],
#        [6.7, 2.5, 5.8, 1.8],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.8, 3. , 5.5, 2.1],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.9, 3.1, 5.1, 2.3],
#        [6.9, 3.1, 4.9, 1.5],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.9, 3.2, 5.7, 2.3],
#        [7. , 3.2, 4.7, 1.4],
#        [7.1, 3. , 5.9, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.2, 3.2, 6. , 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [7.3, 2.9, 6.3, 1.8],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.6, 3. , 6.6, 2.1],
#        [7.7, 2.8, 6.7, 2. ],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [7.7, 3. , 6.1, 2.3],
#        [7.9, 3.8, 6.4, 2. ]])

# %%
! pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\lucio59241446\desktop\datasets\venv\lib\site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lucio59241446\desktop\datasets\venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\lucio59241446\desktop\datasets\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lucio59241446\desktop\datasets\venv\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lucio59241446\desktop\datasets\venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\lucio59241446\desktop\datasets\venv\lib\site-packages (from matplotlib) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lucio59241446\desktop\datasets\venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\lucio59241446\desktop\datasets\venv\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\lucio59241446\desktop\datasets\venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lucio59241446\desktop\datasets\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\lucio59241446\desktop\datasets\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# vamos criar gráficos com matplotlib
import matplotlib.pyplot as plt
plt.hist(data_iris[:,0], bins=10)
plt.title('Histograma da coluna 0 do dataset Iris')
plt.xlabel('Valor')
plt.ylabel('Frequência')
plt.show()

# %%
# mostre a quantidade de elementos na coluna 0 entre 5.5 e 5.6
np.sum((data_iris[:,0] >= 5.5) & (data_iris[:,0] <= 5.8))
# Out:
# np.int64(28)

# %%
# total de elementos na coluna 0
data_iris[:,0].size
# Out:
# 150

# %%
# quantos elementos são maiores que 5.0 na coluna 0
np.sum(data_iris[:,0] > 5.0)
# Out:
# np.int64(118)

# %%
# igual a 4.5
np.sum(data_iris[:,0] == 4.5)
# Out:
# np.int64(1)

# %%
# frequencia de valores com 4.5
np.sum(data_iris[:,0] == 4.5)
# Out:
# np.int64(1)

# %%
# faça o histograma da coluna 1 do dataset Iris
import matplotlib.pyplot as plt
plt.hist(data_iris[:,1], bins=10)
plt.title('Histograma da coluna 1 do dataset Iris')
plt.xlabel('Valor')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# Leitura do Histograma
#
#     Eixo X (Horizontal - "Valor"): Representa os valores da coluna 1 do dataset Iris. O eixo está dividido em intervalos, chamados de bins (compartimentos ou classes).
#
#         Exemplo dos bins: Os valores vão de 2.0 a 4.5, com divisões claras em 2.0, 2.5, 3.0, 3.5, 4.0, e 4.5.
#
#     Eixo Y (Vertical - "Frequência"): Representa a contagem ou o número de ocorrências (frequência) de valores que caem dentro de cada intervalo (bin) do eixo X.
#
# 🔍 Interpretação dos Dados
#
# Analisando a altura das barras, podemos tirar as seguintes conclusões:
#
#     Maior Frequência (Moda): A barra mais alta está centrada ligeiramente acima do valor 3.0.
#
#         Isso significa que a maior concentração de valores na coluna 1 do dataset Iris está no intervalo entre aproximadamente 2.9 e 3.1 (o bin correspondente a 3.0 tem uma frequência de 38, o valor máximo no Y).
#
#     Segunda Maior Frequência: O segundo pico está no intervalo entre 3.0 e 3.5. A barra centrada em 3.25 tem uma frequência de cerca de 31.
#
#     Distribuição dos Dados:
#
#         A distribuição não é perfeitamente simétrica. Ela parece ter um leve viés (assimetria) para a direita (a cauda estende-se um pouco mais para a direita), mas é mais ou menos em forma de sino (distribuição normal) em sua parte principal.
#
#         Valores Baixos: Os valores mais baixos, no intervalo de 2.0 a 2.25, têm uma frequência baixa (cerca de 4).
#
#         Valores Altos: Os valores mais altos (acima de 4.0) também têm uma frequência muito baixa (cerca de 2).
#
#     Conclusão: A maioria dos dados (a maior parte da coluna 1) está concentrada na faixa de 2.5 a 3.5, com um pico muito forte por volta de 3.0.
#
# Em resumo, o histograma mostra que a característica representada pela coluna 1 no dataset Iris varia principalmente entre 2.0 e 4.5, sendo 3.0 o valor mais comum.

# %%
# mostrar quantidade da coluna 1 entre 3.0 e 3.3
np.sum((data_iris[:,1] >= 3.0) & (data_iris[:,1] <= 3.1))
# Out:
# np.int64(38)

# %% [markdown]
# ## Retorno Financeiro e rentabilidade

# %% [markdown]
# - Investimento financeiro
# - Retorno Financeiro
# - Retorno: rentabilidade melhor que a outra
# - Na simulação a cada 5 minutos do terminal os dados vao para a planilha

# %%
! pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\lucio59241446\desktop\datasets\venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\lucio59241446\desktop\datasets\venv\lib\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lucio59241446\desktop\datasets\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lucio59241446\desktop\datasets\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lucio59241446\desktop\datasets\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\lucio59241446\desktop\datasets\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %%
! pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\lucio59241446\desktop\datasets\venv\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\lucio59241446\desktop\datasets\venv\lib\site-packages (from openpyxl) (2.0.0)

# %%
try:
    df = pd.read_excel('datasets/petrobras.xlsx')
except FileNotFoundError:
    print("Erro: arquivo nao foi encontrado.")
except Exception as e:
    print(f"Ocorreu um erro na leitura: {e}")

# %%
df.head(3)
# Out:
#    1.31
# 0  1.34
# 1  1.42
# 2  1.40

# %%
primeira_coluna = df.iloc[:, 0]

# %%
print(type(primeira_coluna))
# Out:
# <class 'pandas.core.series.Series'>

# %%
import numpy as np

# %%
vetor = np.array(primeira_coluna)

# %%
print(type(vetor))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# DESAFIO

# %% [markdown]
# Situação problema
#
# * Joãozinho investiu no ativo da petrobras
# * R$ 100,00 (preço inicial-valor de compra): preco(i-1)
# * R$ 111,00 (preço final)
# * Ganho Bruto: R$ 111,00 - R$ 100,00 (R$ 11,00)
# * ret = R$ 11,00/R$ 100,00 = 0.11 ganho no periodo (valorização)

# %% [markdown]
# ![Alt text](desafioret.png)

# %% [markdown]
# Usar o MatplotLib com o ret (retorno financeiro)
#
# O gráfico deve ficar semelhante ao modelo:

# %% [markdown]
# ![Alt text](desaf_grafico%20(1).png)

# %% [markdown]
# Formula implementada no numpy
# Usar matplotlib
# dica (fig)

# %%
import pandas as pd

# %%
df.head(20)
# Out:
#     1.31
# 0   1.34
# 1   1.42
# 2   1.40
# 3   1.42
# 4   1.40
# 5   1.47
# 6   1.45
# 7   1.48
# 8   1.42
# 9   1.34
# 10  1.34
# 11  1.35
# 12  1.35
# 13  1.36
# 14  1.32
# 15  1.24
# 16  1.22
# 17  1.27
# 18  1.26

# %%
print(df.columns)
# Out:
# Index([1.31], dtype='float64')

# %%
df = pd.read_excel('datasets/petrobras.xlsx', header=None)

# %%
print(df.columns)
# Out:
# Index([0], dtype='int64')

# %%
import matplotlib.pyplot as plt

# 2 - Selecionar o vetor (array) de preços
precos = df[0].values   # <-- nome numérico da coluna
print("Preços:", precos)

# 3 - Calcular o retorno financeiro
ret = (precos[1:] - precos[:-1]) / precos[:-1]
print("Retornos:", ret)

# 4 - Plotar
plt.figure(figsize=(8,4))
plt.plot(ret, marker="o")
plt.title("Retorno Financeiro (ret)")
plt.xlabel("Período")
plt.ylabel("Retorno")
plt.grid(True)
plt.show()
# Out:
# Preços: [1.31 1.34 1.42 1.4  1.42 1.4  1.47 1.45 1.48 1.42 1.34 1.34 1.35 1.35
#  1.36 1.32 1.24 1.22 1.27 1.26]
# Retornos: [ 0.02290076  0.05970149 -0.01408451  0.01428571 -0.01408451  0.05
#  -0.01360544  0.02068966 -0.04054054 -0.05633803  0.          0.00746269
#   0.          0.00740741 -0.02941176 -0.06060606 -0.01612903  0.04098361
#  -0.00787402]
